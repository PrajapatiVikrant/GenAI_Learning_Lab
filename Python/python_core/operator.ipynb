# %% [markdown]
# # Operator

# %% [markdown]
# ## Operator help to applying operation on between two operand

# %%
'''
Airthmatic Opeator

  Addition (+)
  Subtraction (-)
  Multiplication or Product (*)
  division (/)
  modulus (%)
  floor (//)
  Exponent (**)

Comparison Operator
  equal (==)
  greatorthen (>)
  lesserthen (<)
  greatorthen or equal to  (>=)
  lesserthen or equal to (<=)
  not equal (!=)

Logical Operator
and (&&)
or (||)
not equal (!)
'''

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
##  Airthmatic Opeator
print(a+b)
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'Python 3.14.5' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
