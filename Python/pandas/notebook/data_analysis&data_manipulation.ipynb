# %% [markdown]
# # What is Data Manipulation and Analysis?

# %% [markdown]
# ### Data Manipulation
# - Definition: Changing, organizing, or  preparing data to make it useful and easier to understand.
# - Goal: To clean,transform, and structure raw data for better usability.
# - Example:
#    - Organizing a Grocery List: Sorting random items into category like "fruits"  or "Dairy.
#    - Fixing Errors in a student record: Correcting missing or wrong grades

# %% [markdown]
# ### Data Analysis
# - Definition: Exracting patterns, trends and insights from to solve problem
# - Goal: To answer questions or identify trends using the data
# - Example:
#   - Analyzing sales trends: Find the month with the highest revenue
#   - Tracking Fitness Progress: Analysing daily steps and calories for
