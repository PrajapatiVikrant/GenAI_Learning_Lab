# %% [markdown]
# # Series
# - A series is a one-dimensional labeled array that can hold any data type: integers, floats, strings or
# even python objects. Each element in the series has a unique label called an index
# - It is often used to track changes or patterns over time, such as daily temperatures, stock, prices or sales revenue

# %%
import pandas as pd
list = ["Vikrant","Prajapati", 24, "male", "Khekra,Bahpat Uttar Pradesh"]
list = pd.Series(list)
print(list)
# Out:
# 0                        Vikrant
# 1                      Prajapati
# 2                             24
# 3                           male
# 4    Khekra,Bahpat Uttar Pradesh
# dtype: object

# %% [markdown]
# ## Labels
# If nothing else is specified, the values are labeled with their index number, First value has index 0 , second value has index 1 etc.
# This label can be used to access a specified value

# %%
print(list[0])
print(list[1])
print(list[2])
print(list[3])
print(list[4])
# Out:
# Vikrant
# Prajapati
# 24
# male
# Khekra,Bahpat Uttar Pradesh

# %% [markdown]
# ## Create your own labels
# With the index argument, you can name your own labels

# %%
myObject = pd.Series(["Vikrant","Prajapati", 24, "male", "Khekra,Bahpat Uttar Pradesh"], index = ["FirstName","SecondName","age","gender","address"])
print(myObject)
# Out:
# FirstName                         Vikrant
# SecondName                      Prajapati
# age                                    24
# gender                               male
# address       Khekra,Bahpat Uttar Pradesh
# dtype: object

# %%
print(f"My name's {myObject[FirstName]} {myObject[SecondName]} ")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(f"My name's {myObject[FirstName]} {myObject[SecondName]} ")
#
# NameError: name 'FirstName' is not defined
